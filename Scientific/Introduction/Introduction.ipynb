# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="XB Niloofar" size=5>
# 				<p></p>
# 				<p></p>
# «به نام خدا»
# 				<p></p>
# 			</font>
# 			<p></p>
# 			<br />
#             <img src="images/logo.png" style="border-radius: 25px" width="400">
#             <img src="images/banner.png" width="250">
# 			<br />
# زمستان ۱۳۹۷
# 		</div>
# 		<hr/>
# 		<font color=#029C8B size=6>
# 			<br />
# 			<div align=center>
#                محتوای علمی یازدهمین نبرد هوش مصنوعی شریف
#             </div>
# 		</font>
#         <font color=#E7234D size=6>
# 			<br />
# 			<div align=center>
#                  «بخش صفرم: مقدمه»
#             </div>
# 		</font>
# 		<br />
# 		<div align=center>
# محمدرضا کارگر، علی شفیعی، عرفان فرهادی، محمد شریفی کیاسری، میلاد آقاجوهری و سید پارسا میرطاهری
#         </div>
# 		<hr />
# 		<style type="text/css" scoped>
#         p{
#         border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#         };
#         </style>
# 		<div>
# 			<h3>فهرست مطالب</h3>
# 			<ul style="margin-right: 0;">
#                 <li>
# 					<a href="#intro">
#                         مقدمه
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#ai">
#                     هوش مصنوعی؟ من خودم باهوشم!
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#lai">
#                     به دنبال هوش مصنوعی
#                     </a>
# 				</li>
#         </div>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="intro" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# مقدمه
#         </font>
#         <p></p>
#         به نبرد هوش مصنوعی خوش آمدید! امیدواریم آمادهٔ رویارویی با چالش طراحی شده توسط دوستان ما باشید. گفتم آماده؟ نه! لازم نیست از الان آمادهٔ آماده باشید؛ الان مهم این است که مشتاق یاد گرفتن و حل مسئله باشید. چون می‌خواهیم در روز های آینده سعی کنیم با هم یاد بگیریم و برای این چالش آماده شویم. پس با ما همراه باشید!
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="ai" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# هوش مصنوعی؟ من خودم باهوشم!
#         </font>
#         <p></p>
#         سوالی که در ابتدا باید به آن جواب دهیم این است که منظورمان از هوش مصنوعی چیست. مگر خودمان هوش نداریم که محتاج به هوش مصنوعی باشیم؟ اگر به این سوال پاسخ ندهیم، احتمالا تنها کاری که برای خوب عمل کردن در این چالش و چالش‌های مشابه از دستمان برمی‌آید آن است که به لطف هوش سرشار خودمان هر بار چالش پیش رو را درک کنیم و استراتژی‌های بهینه را بفهمیم و به کامپیوتر بی‌نوا دستور دهیم کاری که ما می‌گوییم را انجام دهد. کاری که در اینجا کرده‌ایم پیاده‌سازی نتیجه‌گیری‌های خودمان در قالب کد است. اما آیا می‌شود پا را از این فراتر گذاشت؟ ایدهٔ شما چیست؟
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="lai" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# به دنبال هوش مصنوعی
#         </font>
#         <p></p>
#         استفاده از توانایی‌های کامپیوتر برای پیاده‌سازی استراتژی‌هایی که به آن‌ها می‌رسیم گام ارزشمندی‌ست. چه بسا خیلی وقت‌ها از این راه به نتیجه می‌رسیم. اما جایی که پیچیدگی زیاد مسئله کار را برای هوش انسانی سخت می‌کند، سراغ هوش مصنوعی می‌رویم. در هوش مصنوعی به دنبال آن هستیم که یک عامل «هوشمند» بسازیم. به این معنی که با بستری که در اختیار عامل می‌گذاریم خودش به دنبال عملکرد بهینه بگردد و بهترین استراتژی را پیدا کند. در اینجا هنر ما پیاده‌سازی نحوهٔ جستجو، سنجش و یاد گرفتن عامل است. در محتواهایی که در روزهای آینده در اختیارتان می‌گذاریم سعی کرده ایم از مفاهیم پایه آغاز کرده و با هم تا یادگیری مفاهیم پیشرفته‌تر پیش برویم. بخش نخست محتواها به روش‌های
#        <font color=blue>«جستجوی مطلع و بی‌اطلاع»</font>
#        ، بخش دوم به روش‌های
#        <font color=red>«جستجوی رقابتی»</font>
#         و بخش سوم و پایانی به
#        <font color=green>«فرایند‌های تصمیم‌گیری مارکوف و یادگیری تقویتی»</font>
#         اختصاص دارد. امیدواریم این محتواها به آشنایی شما با «هوش مصنوعی» و آماده شدن برای چالش هوش مصنوعی امسال کمک کنند و از آن‌ها لذت ببرید!
# 	</font>
# </div>
